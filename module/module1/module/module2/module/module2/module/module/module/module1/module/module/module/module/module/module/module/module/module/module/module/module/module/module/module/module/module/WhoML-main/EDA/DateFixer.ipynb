# %%
import pandas as pd

df = pd.read_csv('../data/WhoDataSet.csv', parse_dates=['date'])
df.set_index('episode_id', inplace=True)
df.head()
# Out:
#                            title  season  doctorid  is_special  is_earth  \
# episode_id
# 1.01                        Rose       1         9           0         1
# 1.02        The End of the World       1         9           0         0
# 1.03            The Unquiet Dead       1         9           0         1
# 1.04            Aliens of London       1         9           0         1
# 1.05             World War Three       1         9           0         1
#
#             is_space  is_past  is_present  is_future  is_outside_time  ...  \
# episode_id                                                             ...
# 1.01               0        0           1          0                0  ...
# 1.02               1        0           0          1                0  ...
# 1.03               0        1           0          0                0  ...
# 1.04               0        0           1          0                0  ...
# ...

# %%
df['Weekday'] = df['date'].dt.day_name()
df.head()
# Out:
#                            title  season  doctorid  is_special  is_earth  \
# episode_id
# 1.01                        Rose       1         9           0         1
# 1.02        The End of the World       1         9           0         0
# 1.03            The Unquiet Dead       1         9           0         1
# 1.04            Aliens of London       1         9           0         1
# 1.05             World War Three       1         9           0         1
#
#             is_space  is_past  is_present  is_future  is_outside_time  ...  \
# episode_id                                                             ...
# 1.01               0        0           1          0                0  ...
# 1.02               1        0           0          1                0  ...
# 1.03               0        1           0          0                0  ...
# 1.04               0        0           1          0                0  ...
# ...

# %%
df[df['Weekday'] == 'Monday'][['title','Producer','rating']].sort_values(by='rating', ascending=False).head(6)
# Out:
#                         title        Producer  rating
# episode_id
# 3.0         The Runaway Bride  Phil Collinson     7.6

# %%
df.to_csv('../data/WhoDataSetCategorical.csv')
